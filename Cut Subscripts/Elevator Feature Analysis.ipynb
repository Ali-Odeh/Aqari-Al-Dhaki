# %% [markdown]
# # Analyzing the Effect of Elevator on Predicted Prices
# This notebook is a **cut subscript** extracted from the main price prediction project. It depends on variables, preprocessing, and models defined elsewhere, so running it independently will cause **errors**.

# %%
city_categories = [col.replace('المدينة_', '') for col in X.columns if col.startswith('المدينة_')]

example_input = {
    'عدد الغرف': 5,
    'عدد الحمامات': 2,
    'مفروشة': 0,
    'مساحة البناء': 120,
    'الطابق': 3,
    'عمر البناء': 5,
    'العقار مرهون': False,
    'طريقة الدفع': 0,
    'مصعد': True,
    'موقف سيارات': False,   # only used for post-prediction adjustment
    'المدينة': 'رام الله'
}

feature_cols_for_prediction = [col for col in X.columns if col != 'موقف سيارات']

predicted_price = predict_price(final_model, example_input, city_categories, feature_columns=feature_cols_for_prediction)
print(f"Predicted Price (شيكل): {predicted_price:.2f}")
# Out:
# Predicted Price (شيكل): 247133.34

# %%
city_categories = [col.replace('المدينة_', '') for col in X.columns if col.startswith('المدينة_')]

example_input = {
    'عدد الغرف': 5,
    'عدد الحمامات': 2,
    'مفروشة': 0,
    'مساحة البناء': 120,
    'الطابق': 3,
    'عمر البناء': 5,
    'العقار مرهون': False,
    'طريقة الدفع': 0,
    'مصعد': False,
    'موقف سيارات': False,   # only used for post-prediction adjustment
    'المدينة': 'رام الله'
}

feature_cols_for_prediction = [col for col in X.columns if col != 'موقف سيارات']

predicted_price = predict_price(final_model, example_input, city_categories, feature_columns=feature_cols_for_prediction)
print(f"Predicted Price (شيكل): {predicted_price:.2f}")
# Out:
# Predicted Price (شيكل): 201836.84

# %% [markdown]
# Currently the elevator feature seems to a have an unrealistic effect on the price, so we are going to analyze it's effect on price more closely so we can use that in post predection adjustment instead of using it in the training directly

# %%
df['مصعد'].value_counts()
# Out:
# مصعد
# True     783
# False    460
# Name: count, dtype: int64

# %%
df.groupby('مصعد')['السعر بالشيكل'].describe()
# Out:
#        count           mean            std     min       25%       50%  \
# مصعد
# False  460.0  385422.417391  197408.161910  5222.0  234385.0  349865.5
# True   783.0  449183.720307  275383.160365  6124.0  311197.0  426604.0
#
#              75%        max
# مصعد
# False  487127.25  1038688.0
# True   558721.50  5007960.0

# %% [markdown]
# ## Define function to find similar property pairs
# This function:
# - Splits data into two groups (with an elevator / without an elevator).
# - Converts boolean features to integers for easier comparison.
# - Can limit comparisons to the same floor
# - Matches each non-elevator sample with a elevator sample having nearly identical features within a given tolerance.

# %%
def find_similar_pairs_elevator(
    df,
    feature_cols,
    elevator_col="مصعد",
    floor_col="الطابق",
    same_floor=True,
    floor_value=None,
    normalize=True,
    tolerance=0.10,
    max_pairs=100,
    top_k_per_no=3,
):
    df_no = df[df[elevator_col].astype(int) == 0].copy()
    df_yes = df[df[elevator_col].astype(int) == 1].copy()

    # optionally filter by floor_value
    if floor_value is not None:
        df_no = df_no[df_no[floor_col] == floor_value]
        df_yes = df_yes[df_yes[floor_col] == floor_value]

    # nothing to match
    if df_no.shape[0] == 0 or df_yes.shape[0] == 0:
        return []

    # comparison columns
    comp_cols = [c for c in feature_cols if c not in {elevator_col, floor_col}]

    # copy and convert bools to ints
    df_no_comp = df_no[comp_cols].copy()
    df_yes_comp = df_yes[comp_cols].copy()

    bool_cols = df_no_comp.select_dtypes(include=['bool']).columns.tolist()
    for c in bool_cols:
        df_no_comp[c] = df_no_comp[c].astype(int)
        df_yes_comp[c] = df_yes_comp[c].astype(int)

    # ensure same column order
    df_yes_comp = df_yes_comp[comp_cols]
    df_no_comp = df_no_comp[comp_cols]

    if normalize:
        numeric_cols = df_no_comp.select_dtypes(include=[np.number]).columns.tolist()
        # compute min/max across both sets
        mins = pd.concat([df_no_comp[numeric_cols], df_yes_comp[numeric_cols]], axis=0).min()
        maxs = pd.concat([df_no_comp[numeric_cols], df_yes_comp[numeric_cols]], axis=0).max()
        ranges = (maxs - mins).replace(0, 1.0)  # avoid divide-by-zero

        # apply (value - min) / range
        df_no_norm = df_no_comp.copy()
        df_yes_norm = df_yes_comp.copy()
        for col in numeric_cols:
            df_no_norm[col] = (df_no_comp[col] - mins[col]) / ranges[col]
            df_yes_norm[col] = (df_yes_comp[col] - mins[col]) / ranges[col]
    else:
        df_no_norm = df_no_comp.copy()
        df_yes_norm = df_yes_comp.copy()

    yes_vals = df_yes_norm.values
    yes_index = df_yes_norm.index.to_numpy()
    pairs = []

    for idx_no in df_no_norm.index:
        no_vec = df_no_norm.loc[idx_no].values  

        dists = np.abs(yes_vals - no_vec).sum(axis=1) 

        candidate_mask = dists <= tolerance
        if candidate_mask.sum() == 0:
            # optionally allow fallback to take top-k nearest
            top_k = np.argsort(dists)[:top_k_per_no]
            selected_idxs = top_k
        else:
            # order the masked candidates by distance and take top_k_per_no
            candidate_idxs = np.where(candidate_mask)[0]
            ordered = candidate_idxs[np.argsort(dists[candidate_idxs])]
            selected_idxs = ordered[:top_k_per_no]

        for sel in selected_idxs:
            idx_yes = yes_index[sel]
            dist = float(dists[sel])
            pairs.append((idx_no, idx_yes, dist))
            if len(pairs) >= max_pairs:
                return pairs

    return pairs

# %%
numeric_feature_cols = [
    "عدد الغرف",
    "عدد الحمامات",
    "مفروشة",
    "مساحة البناء",
    "الطابق",
    "عمر البناء",
    "العقار مرهون",
    "مصعد",
    "موقف سيارات"
]

all_pairs_by_floor = {}  # use dict, not list
for f in sorted(df["الطابق"].dropna().unique()):
    pair = find_similar_pairs_elevator(df, numeric_feature_cols,
                                     elevator_col="مصعد",
                                     floor_col="الطابق",
                                     floor_value=f,
                                     normalize=True,
                                     tolerance=0.08,
                                     max_pairs=200,
                                     top_k_per_no=2)
    all_pairs_by_floor[f] = pair
    print(f, "pairs:", len(pair))
# Out:
# -2 pairs: 16
# -1 pairs: 20
# 0 pairs: 94
# 1 pairs: 186
# 2 pairs: 156
# 3 pairs: 105
# 4 pairs: 95
# 5 pairs: 56
# 6 pairs: 73
# 7 pairs: 36
# 8 pairs: 0
# 9 pairs: 24
# 10 pairs: 6
# 11 pairs: 22

# %%
price_col = "السعر بالشيكل"
all_stats = {}

for f, pairs in all_pairs_by_floor.items():
    percent_diffs = []
    print("="*80)
    print(f"Floor {f} → {len(pairs)} matched pairs")
    print("="*80)

    for idx_no, idx_yes, _dist in pairs:
        no_row = df.loc[idx_no].copy()
        yes_row = df.loc[idx_yes].copy()

        actual_no = no_row[price_col]
        actual_yes = yes_row[price_col]

        if actual_no > 0:
            percent_diff = (actual_yes - actual_no) / actual_no * 100
            percent_diffs.append(percent_diff)

        # Detailed comparison
        print(f"Pair: No elevator idx {idx_no}, Elevator idx {idx_yes}")
        print(f"Actual prices: No elevator {actual_no}, Elevator {actual_yes}")
        print(f"Actual difference: {actual_yes - actual_no:.0f}")
        print(f"Actual percent difference: {percent_diff:.2f}%")
        print('-'*50)

    if percent_diffs:
        stats = {
            "mean": np.mean(percent_diffs),
            "median": np.median(percent_diffs),
            "min": np.min(percent_diffs),
            "max": np.max(percent_diffs),
            "count": len(percent_diffs)
        }
        all_stats[f] = stats
        print(f"Summary for floor {f}:")
        print(f"  Mean elevator effect:   {stats['mean']:.2f}%")
        print(f"  Median elevator effect: {stats['median']:.2f}%")
        print(f"  Min effect: {stats['min']:.2f}%")
        print(f"  Max effect: {stats['max']:.2f}%")
    else:
        all_stats[f] = {}
        print("⚠️ No valid pairs on this floor.")
# Out:
# ================================================================================
# Floor -2 → 16 matched pairs
# ================================================================================
# Pair: No elevator idx 8, Elevator idx 272
# Actual prices: No elevator 156898, Elevator 352412
# Actual difference: 195514
# Actual percent difference: 124.61%
# --------------------------------------------------
# Pair: No elevator idx 8, Elevator idx 304
# Actual prices: No elevator 156898, Elevator 250000
# Actual difference: 93102
# Actual percent difference: 59.34%
# --------------------------------------------------
# Pair: No elevator idx 16, Elevator idx 272
# Actual prices: No elevator 204028, Elevator 352412
# Actual difference: 148384
# Actual percent difference: 72.73%
# --------------------------------------------------
# Pair: No elevator idx 16, Elevator idx 192
# Actual prices: No elevator 204028, Elevator 463700
# Actual difference: 259672
# Actual percent difference: 127.27%
# --------------------------------------------------
# Pair: No elevator idx 18, Elevator idx 272
# Actual prices: No elevator 352412, Elevator 352412
# Actual difference: 0
# Actual percent difference: 0.00%
# --------------------------------------------------
# Pair: No elevator idx 18, Elevator idx 192
# Actual prices: No elevator 352412, Elevator 463700
# Actual difference: 111288
# Actual percent difference: 31.58%
# --------------------------------------------------
# Pair: No elevator idx 20, Elevator idx 176
# Actual prices: No elevator 649180, Elevator 463700
# Actual difference: -185480
# Actual percent difference: -28.57%
# --------------------------------------------------
# Pair: No elevator idx 20, Elevator idx 216
# Actual prices: No elevator 649180, Elevator 511925
# Actual difference: -137255
# Actual percent difference: -21.14%
# --------------------------------------------------
# Pair: No elevator idx 120, Elevator idx 272
# Actual prices: No elevator 389508, Elevator 352412
# Actual difference: -37096
# Actual percent difference: -9.52%
# --------------------------------------------------
# Pair: No elevator idx 120, Elevator idx 192
# Actual prices: No elevator 389508, Elevator 463700
# Actual difference: 74192
# Actual percent difference: 19.05%
# --------------------------------------------------
# Pair: No elevator idx 235, Elevator idx 216
# Actual prices: No elevator 363541, Elevator 511925
# Actual difference: 148384
# Actual percent difference: 40.82%
# --------------------------------------------------
# Pair: No elevator idx 235, Elevator idx 192
# Actual prices: No elevator 363541, Elevator 463700
# Actual difference: 100159
# Actual percent difference: 27.55%
# --------------------------------------------------
# Pair: No elevator idx 724, Elevator idx 304
# Actual prices: No elevator 159684, Elevator 250000
# Actual difference: 90316
# Actual percent difference: 56.56%
# --------------------------------------------------
# Pair: No elevator idx 724, Elevator idx 272
# Actual prices: No elevator 159684, Elevator 352412
# Actual difference: 192728
# Actual percent difference: 120.69%
# --------------------------------------------------
# Pair: No elevator idx 755, Elevator idx 272
# Actual prices: No elevator 157970, Elevator 352412
# Actual difference: 194442
# Actual percent difference: 123.09%
# --------------------------------------------------
# Pair: No elevator idx 755, Elevator idx 304
# Actual prices: No elevator 157970, Elevator 250000
# Actual difference: 92030
# Actual percent difference: 58.26%
# --------------------------------------------------
# Summary for floor -2:
#   Mean elevator effect:   50.14%
#   Median elevator effect: 48.69%
#   Min effect: -28.57%
#   Max effect: 127.27%
# ================================================================================
# Floor -1 → 20 matched pairs
# ================================================================================
# Pair: No elevator idx 68, Elevator idx 340
# Actual prices: No elevator 370960, Elevator 686276
# Actual difference: 315316
# Actual percent difference: 85.00%
# --------------------------------------------------
# Pair: No elevator idx 68, Elevator idx 464
# Actual prices: No elevator 370960, Elevator 44455
# Actual difference: -326505
# Actual percent difference: -88.02%
# --------------------------------------------------
# Pair: No elevator idx 166, Elevator idx 340
# Actual prices: No elevator 392246, Elevator 686276
# Actual difference: 294030
# Actual percent difference: 74.96%
# --------------------------------------------------
# Pair: No elevator idx 166, Elevator idx 513
# Actual prices: No elevator 392246, Elevator 222576
# Actual difference: -169670
# Actual percent difference: -43.26%
# --------------------------------------------------
# Pair: No elevator idx 353, Elevator idx 736
# Actual prices: No elevator 74192, Elevator 98355
# Actual difference: 24163
# Actual percent difference: 32.57%
# --------------------------------------------------
# Pair: No elevator idx 353, Elevator idx 548
# Actual prices: No elevator 74192, Elevator 100000
# Actual difference: 25808
# Actual percent difference: 34.79%
# --------------------------------------------------
# Pair: No elevator idx 356, Elevator idx 340
# Actual prices: No elevator 465465, Elevator 686276
# Actual difference: 220811
# Actual percent difference: 47.44%
# --------------------------------------------------
# Pair: No elevator idx 356, Elevator idx 260
# Actual prices: No elevator 465465, Elevator 350000
# Actual difference: -115465
# Actual percent difference: -24.81%
# --------------------------------------------------
# Pair: No elevator idx 357, Elevator idx 260
# Actual prices: No elevator 600000, Elevator 350000
# Actual difference: -250000
# Actual percent difference: -41.67%
# --------------------------------------------------
# Pair: No elevator idx 357, Elevator idx 322
# Actual prices: No elevator 600000, Elevator 612084
# Actual difference: 12084
# Actual percent difference: 2.01%
# --------------------------------------------------
# Pair: No elevator idx 391, Elevator idx 260
# Actual prices: No elevator 470695, Elevator 350000
# Actual difference: -120695
# Actual percent difference: -25.64%
# --------------------------------------------------
# Pair: No elevator idx 391, Elevator idx 314
# Actual prices: No elevator 470695, Elevator 593536
# Actual difference: 122841
# Actual percent difference: 26.10%
# --------------------------------------------------
# Pair: No elevator idx 774, Elevator idx 340
# Actual prices: No elevator 466032, Elevator 686276
# Actual difference: 220244
# Actual percent difference: 47.26%
# --------------------------------------------------
# Pair: No elevator idx 774, Elevator idx 260
# Actual prices: No elevator 466032, Elevator 350000
# Actual difference: -116032
# Actual percent difference: -24.90%
# --------------------------------------------------
# Pair: No elevator idx 792, Elevator idx 340
# Actual prices: No elevator 470455, Elevator 686276
# Actual difference: 215821
# Actual percent difference: 45.87%
# --------------------------------------------------
# Pair: No elevator idx 792, Elevator idx 260
# Actual prices: No elevator 470455, Elevator 350000
# Actual difference: -120455
# Actual percent difference: -25.60%
# --------------------------------------------------
# Pair: No elevator idx 847, Elevator idx 260
# Actual prices: No elevator 630068, Elevator 350000
# Actual difference: -280068
# Actual percent difference: -44.45%
# --------------------------------------------------
# Pair: No elevator idx 847, Elevator idx 322
# Actual prices: No elevator 630068, Elevator 612084
# Actual difference: -17984
# Actual percent difference: -2.85%
# --------------------------------------------------
# Pair: No elevator idx 869, Elevator idx 260
# Actual prices: No elevator 589194, Elevator 350000
# Actual difference: -239194
# Actual percent difference: -40.60%
# --------------------------------------------------
# Pair: No elevator idx 869, Elevator idx 322
# Actual prices: No elevator 589194, Elevator 612084
# Actual difference: 22890
# Actual percent difference: 3.88%
# --------------------------------------------------
# Summary for floor -1:
#   Mean elevator effect:   1.90%
#   Median elevator effect: -0.42%
#   Min effect: -88.02%
#   Max effect: 85.00%
# ================================================================================
# Floor 0 → 94 matched pairs
# ================================================================================
# Pair: No elevator idx 32, Elevator idx 105
# Actual prices: No elevator 667728, Elevator 500796
# Actual difference: -166932
# Actual percent difference: -25.00%
# --------------------------------------------------
# Pair: No elevator idx 32, Elevator idx 1080
# Actual prices: No elevator 667728, Elevator 324527
# Actual difference: -343201
# Actual percent difference: -51.40%
# --------------------------------------------------
# Pair: No elevator idx 33, Elevator idx 105
# Actual prices: No elevator 382089, Elevator 500796
# Actual difference: 118707
# Actual percent difference: 31.07%
# --------------------------------------------------
# Pair: No elevator idx 33, Elevator idx 1080
# Actual prices: No elevator 382089, Elevator 324527
# Actual difference: -57562
# Actual percent difference: -15.07%
# --------------------------------------------------
# Pair: No elevator idx 58, Elevator idx 388
# Actual prices: No elevator 630632, Elevator 556440
# Actual difference: -74192
# Actual percent difference: -11.76%
# --------------------------------------------------
# Pair: No elevator idx 58, Elevator idx 323
# Actual prices: No elevator 630632, Elevator 727082
# Actual difference: 96450
# Actual percent difference: 15.29%
# --------------------------------------------------
# Pair: No elevator idx 67, Elevator idx 173
# Actual prices: No elevator 741920, Elevator 612084
# Actual difference: -129836
# Actual percent difference: -17.50%
# --------------------------------------------------
# Pair: No elevator idx 67, Elevator idx 1066
# Actual prices: No elevator 741920, Elevator 156100
# Actual difference: -585820
# Actual percent difference: -78.96%
# --------------------------------------------------
# Pair: No elevator idx 78, Elevator idx 514
# Actual prices: No elevator 649180, Elevator 537892
# Actual difference: -111288
# Actual percent difference: -17.14%
# --------------------------------------------------
# Pair: No elevator idx 78, Elevator idx 1080
# Actual prices: No elevator 649180, Elevator 324527
# Actual difference: -324653
# Actual percent difference: -50.01%
# --------------------------------------------------
# Pair: No elevator idx 92, Elevator idx 866
# Actual prices: No elevator 222576, Elevator 402221
# Actual difference: 179645
# Actual percent difference: 80.71%
# --------------------------------------------------
# Pair: No elevator idx 92, Elevator idx 560
# Actual prices: No elevator 222576, Elevator 392246
# Actual difference: 169670
# Actual percent difference: 76.23%
# --------------------------------------------------
# Pair: No elevator idx 96, Elevator idx 561
# Actual prices: No elevator 667728, Elevator 720000
# Actual difference: 52272
# Actual percent difference: 7.83%
# --------------------------------------------------
# Pair: No elevator idx 96, Elevator idx 830
# Actual prices: No elevator 667728, Elevator 722988
# Actual difference: 55260
# Actual percent difference: 8.28%
# --------------------------------------------------
# Pair: No elevator idx 110, Elevator idx 388
# Actual prices: No elevator 667728, Elevator 556440
# Actual difference: -111288
# Actual percent difference: -16.67%
# --------------------------------------------------
# Pair: No elevator idx 110, Elevator idx 323
# Actual prices: No elevator 667728, Elevator 727082
# Actual difference: 59354
# Actual percent difference: 8.89%
# --------------------------------------------------
# Pair: No elevator idx 117, Elevator idx 265
# Actual prices: No elevator 408056, Elevator 275000
# Actual difference: -133056
# Actual percent difference: -32.61%
# --------------------------------------------------
# Pair: No elevator idx 117, Elevator idx 105
# Actual prices: No elevator 408056, Elevator 500796
# Actual difference: 92740
# Actual percent difference: 22.73%
# --------------------------------------------------
# Pair: No elevator idx 126, Elevator idx 105
# Actual prices: No elevator 556440, Elevator 500796
# Actual difference: -55644
# Actual percent difference: -10.00%
# --------------------------------------------------
# Pair: No elevator idx 126, Elevator idx 1033
# Actual prices: No elevator 556440, Elevator 410104
# Actual difference: -146336
# Actual percent difference: -26.30%
# --------------------------------------------------
# Pair: No elevator idx 127, Elevator idx 69
# Actual prices: No elevator 370960, Elevator 561000
# Actual difference: 190040
# Actual percent difference: 51.23%
# --------------------------------------------------
# Pair: No elevator idx 132, Elevator idx 1053
# Actual prices: No elevator 333864, Elevator 148983
# Actual difference: -184881
# Actual percent difference: -55.38%
# --------------------------------------------------
# Pair: No elevator idx 132, Elevator idx 1092
# Actual prices: No elevator 333864, Elevator 147480
# Actual difference: -186384
# Actual percent difference: -55.83%
# --------------------------------------------------
# Pair: No elevator idx 136, Elevator idx 1014
# Actual prices: No elevator 927400, Elevator 407977
# Actual difference: -519423
# Actual percent difference: -56.01%
# --------------------------------------------------
# Pair: No elevator idx 136, Elevator idx 571
# Actual prices: No elevator 927400, Elevator 413166
# Actual difference: -514234
# Actual percent difference: -55.45%
# --------------------------------------------------
# Pair: No elevator idx 148, Elevator idx 742
# Actual prices: No elevator 224888, Elevator 439430
# Actual difference: 214542
# Actual percent difference: 95.40%
# --------------------------------------------------
# Pair: No elevator idx 155, Elevator idx 172
# Actual prices: No elevator 927400, Elevator 927400
# Actual difference: 0
# Actual percent difference: 0.00%
# --------------------------------------------------
# Pair: No elevator idx 155, Elevator idx 265
# Actual prices: No elevator 927400, Elevator 275000
# Actual difference: -652400
# Actual percent difference: -70.35%
# --------------------------------------------------
# Pair: No elevator idx 168, Elevator idx 400
# Actual prices: No elevator 566450, Elevator 566400
# Actual difference: -50
# Actual percent difference: -0.01%
# --------------------------------------------------
# Pair: No elevator idx 168, Elevator idx 1101
# Actual prices: No elevator 566450, Elevator 149728
# Actual difference: -416722
# Actual percent difference: -73.57%
# --------------------------------------------------
# Pair: No elevator idx 188, Elevator idx 173
# Actual prices: No elevator 392246, Elevator 612084
# Actual difference: 219838
# Actual percent difference: 56.05%
# --------------------------------------------------
# Pair: No elevator idx 188, Elevator idx 438
# Actual prices: No elevator 392246, Elevator 366096
# Actual difference: -26150
# Actual percent difference: -6.67%
# --------------------------------------------------
# Pair: No elevator idx 276, Elevator idx 265
# Actual prices: No elevator 964496, Elevator 275000
# Actual difference: -689496
# Actual percent difference: -71.49%
# --------------------------------------------------
# Pair: No elevator idx 276, Elevator idx 105
# Actual prices: No elevator 964496, Elevator 500796
# Actual difference: -463700
# Actual percent difference: -48.08%
# --------------------------------------------------
# Pair: No elevator idx 408, Elevator idx 975
# Actual prices: No elevator 5222, Elevator 414579
# Actual difference: 409357
# Actual percent difference: 7839.08%
# --------------------------------------------------
# Pair: No elevator idx 408, Elevator idx 571
# Actual prices: No elevator 5222, Elevator 413166
# Actual difference: 407944
# Actual percent difference: 7812.03%
# --------------------------------------------------
# Pair: No elevator idx 574, Elevator idx 1080
# Actual prices: No elevator 36000, Elevator 324527
# Actual difference: 288527
# Actual percent difference: 801.46%
# --------------------------------------------------
# Pair: No elevator idx 574, Elevator idx 364
# Actual prices: No elevator 36000, Elevator 329481
# Actual difference: 293481
# Actual percent difference: 815.23%
# --------------------------------------------------
# Pair: No elevator idx 596, Elevator idx 514
# Actual prices: No elevator 912400, Elevator 537892
# Actual difference: -374508
# Actual percent difference: -41.05%
# --------------------------------------------------
# Pair: No elevator idx 596, Elevator idx 1080
# Actual prices: No elevator 912400, Elevator 324527
# Actual difference: -587873
# Actual percent difference: -64.43%
# --------------------------------------------------
# Pair: No elevator idx 598, Elevator idx 1080
# Actual prices: No elevator 556440, Elevator 324527
# Actual difference: -231913
# Actual percent difference: -41.68%
# --------------------------------------------------
# Pair: No elevator idx 598, Elevator idx 364
# Actual prices: No elevator 556440, Elevator 329481
# Actual difference: -226959
# Actual percent difference: -40.79%
# --------------------------------------------------
# Pair: No elevator idx 619, Elevator idx 105
# Actual prices: No elevator 723372, Elevator 500796
# Actual difference: -222576
# Actual percent difference: -30.77%
# --------------------------------------------------
# Pair: No elevator idx 619, Elevator idx 1080
# Actual prices: No elevator 723372, Elevator 324527
# Actual difference: -398845
# Actual percent difference: -55.14%
# --------------------------------------------------
# Pair: No elevator idx 624, Elevator idx 105
# Actual prices: No elevator 593536, Elevator 500796
# Actual difference: -92740
# Actual percent difference: -15.62%
# --------------------------------------------------
# Pair: No elevator idx 624, Elevator idx 1080
# Actual prices: No elevator 593536, Elevator 324527
# Actual difference: -269009
# Actual percent difference: -45.32%
# --------------------------------------------------
# Pair: No elevator idx 631, Elevator idx 1080
# Actual prices: No elevator 315316, Elevator 324527
# Actual difference: 9211
# Actual percent difference: 2.92%
# --------------------------------------------------
# Pair: No elevator idx 631, Elevator idx 364
# Actual prices: No elevator 315316, Elevator 329481
# Actual difference: 14165
# Actual percent difference: 4.49%
# --------------------------------------------------
# Pair: No elevator idx 636, Elevator idx 1080
# Actual prices: No elevator 493377, Elevator 324527
# Actual difference: -168850
# Actual percent difference: -34.22%
# --------------------------------------------------
# Pair: No elevator idx 636, Elevator idx 364
# Actual prices: No elevator 493377, Elevator 329481
# Actual difference: -163896
# Actual percent difference: -33.22%
# --------------------------------------------------
# Pair: No elevator idx 643, Elevator idx 61
# Actual prices: No elevator 452200, Elevator 275000
# Actual difference: -177200
# Actual percent difference: -39.19%
# --------------------------------------------------
# Pair: No elevator idx 654, Elevator idx 265
# Actual prices: No elevator 370960, Elevator 275000
# Actual difference: -95960
# Actual percent difference: -25.87%
# --------------------------------------------------
# Pair: No elevator idx 654, Elevator idx 105
# Actual prices: No elevator 370960, Elevator 500796
# Actual difference: 129836
# Actual percent difference: 35.00%
# --------------------------------------------------
# Pair: No elevator idx 667, Elevator idx 265
# Actual prices: No elevator 251037, Elevator 275000
# Actual difference: 23963
# Actual percent difference: 9.55%
# --------------------------------------------------
# Pair: No elevator idx 667, Elevator idx 105
# Actual prices: No elevator 251037, Elevator 500796
# Actual difference: 249759
# Actual percent difference: 99.49%
# --------------------------------------------------
# Pair: No elevator idx 668, Elevator idx 514
# Actual prices: No elevator 666000, Elevator 537892
# Actual difference: -128108
# Actual percent difference: -19.24%
# --------------------------------------------------
# Pair: No elevator idx 668, Elevator idx 1080
# Actual prices: No elevator 666000, Elevator 324527
# Actual difference: -341473
# Actual percent difference: -51.27%
# --------------------------------------------------
# Pair: No elevator idx 676, Elevator idx 105
# Actual prices: No elevator 741920, Elevator 500796
# Actual difference: -241124
# Actual percent difference: -32.50%
# --------------------------------------------------
# Pair: No elevator idx 676, Elevator idx 514
# Actual prices: No elevator 741920, Elevator 537892
# Actual difference: -204028
# Actual percent difference: -27.50%
# --------------------------------------------------
# Pair: No elevator idx 680, Elevator idx 1080
# Actual prices: No elevator 816112, Elevator 324527
# Actual difference: -491585
# Actual percent difference: -60.23%
# --------------------------------------------------
# Pair: No elevator idx 680, Elevator idx 364
# Actual prices: No elevator 816112, Elevator 329481
# Actual difference: -486631
# Actual percent difference: -59.63%
# --------------------------------------------------
# Pair: No elevator idx 686, Elevator idx 105
# Actual prices: No elevator 413166, Elevator 500796
# Actual difference: 87630
# Actual percent difference: 21.21%
# --------------------------------------------------
# Pair: No elevator idx 686, Elevator idx 571
# Actual prices: No elevator 413166, Elevator 413166
# Actual difference: 0
# Actual percent difference: 0.00%
# --------------------------------------------------
# Pair: No elevator idx 687, Elevator idx 105
# Actual prices: No elevator 278220, Elevator 500796
# Actual difference: 222576
# Actual percent difference: 80.00%
# --------------------------------------------------
# Pair: No elevator idx 687, Elevator idx 1080
# Actual prices: No elevator 278220, Elevator 324527
# Actual difference: 46307
# Actual percent difference: 16.64%
# --------------------------------------------------
# Pair: No elevator idx 694, Elevator idx 1080
# Actual prices: No elevator 296768, Elevator 324527
# Actual difference: 27759
# Actual percent difference: 9.35%
# --------------------------------------------------
# Pair: No elevator idx 694, Elevator idx 364
# Actual prices: No elevator 296768, Elevator 329481
# Actual difference: 32713
# Actual percent difference: 11.02%
# --------------------------------------------------
# Pair: No elevator idx 705, Elevator idx 1080
# Actual prices: No elevator 500796, Elevator 324527
# Actual difference: -176269
# Actual percent difference: -35.20%
# --------------------------------------------------
# Pair: No elevator idx 705, Elevator idx 364
# Actual prices: No elevator 500796, Elevator 329481
# Actual difference: -171315
# Actual percent difference: -34.21%
# --------------------------------------------------
# Pair: No elevator idx 767, Elevator idx 265
# Actual prices: No elevator 255317, Elevator 275000
# Actual difference: 19683
# Actual percent difference: 7.71%
# --------------------------------------------------
# Pair: No elevator idx 767, Elevator idx 105
# Actual prices: No elevator 255317, Elevator 500796
# Actual difference: 245479
# Actual percent difference: 96.15%
# --------------------------------------------------
# Pair: No elevator idx 791, Elevator idx 265
# Actual prices: No elevator 248917, Elevator 275000
# Actual difference: 26083
# Actual percent difference: 10.48%
# --------------------------------------------------
# Pair: No elevator idx 791, Elevator idx 105
# Actual prices: No elevator 248917, Elevator 500796
# Actual difference: 251879
# Actual percent difference: 101.19%
# --------------------------------------------------
# Pair: No elevator idx 816, Elevator idx 1033
# Actual prices: No elevator 5275, Elevator 410104
# Actual difference: 404829
# Actual percent difference: 7674.48%
# --------------------------------------------------
# Pair: No elevator idx 816, Elevator idx 560
# Actual prices: No elevator 5275, Elevator 392246
# Actual difference: 386971
# Actual percent difference: 7335.94%
# --------------------------------------------------
# Pair: No elevator idx 865, Elevator idx 69
# Actual prices: No elevator 374876, Elevator 561000
# Actual difference: 186124
# Actual percent difference: 49.65%
# --------------------------------------------------
# Pair: No elevator idx 873, Elevator idx 768
# Actual prices: No elevator 370730, Elevator 360286
# Actual difference: -10444
# Actual percent difference: -2.82%
# --------------------------------------------------
# Pair: No elevator idx 873, Elevator idx 960
# Actual prices: No elevator 370730, Elevator 373318
# Actual difference: 2588
# Actual percent difference: 0.70%
# --------------------------------------------------
# Pair: No elevator idx 897, Elevator idx 975
# Actual prices: No elevator 5374, Elevator 414579
# Actual difference: 409205
# Actual percent difference: 7614.53%
# --------------------------------------------------
# Pair: No elevator idx 897, Elevator idx 571
# Actual prices: No elevator 5374, Elevator 413166
# Actual difference: 407792
# Actual percent difference: 7588.24%
# --------------------------------------------------
# Pair: No elevator idx 981, Elevator idx 105
# Actual prices: No elevator 417410, Elevator 500796
# Actual difference: 83386
# Actual percent difference: 19.98%
# --------------------------------------------------
# Pair: No elevator idx 981, Elevator idx 571
# Actual prices: No elevator 417410, Elevator 413166
# Actual difference: -4244
# Actual percent difference: -1.02%
# --------------------------------------------------
# Pair: No elevator idx 983, Elevator idx 1080
# Actual prices: No elevator 36100, Elevator 324527
# Actual difference: 288427
# Actual percent difference: 798.97%
# --------------------------------------------------
# Pair: No elevator idx 983, Elevator idx 364
# Actual prices: No elevator 36100, Elevator 329481
# Actual difference: 293381
# Actual percent difference: 812.69%
# --------------------------------------------------
# Pair: No elevator idx 1002, Elevator idx 105
# Actual prices: No elevator 413490, Elevator 500796
# Actual difference: 87306
# Actual percent difference: 21.11%
# --------------------------------------------------
# Pair: No elevator idx 1002, Elevator idx 571
# Actual prices: No elevator 413490, Elevator 413166
# Actual difference: -324
# Actual percent difference: -0.08%
# --------------------------------------------------
# Pair: No elevator idx 1013, Elevator idx 514
# Actual prices: No elevator 34746, Elevator 537892
# Actual difference: 503146
# Actual percent difference: 1448.07%
# --------------------------------------------------
# Pair: No elevator idx 1013, Elevator idx 1080
# Actual prices: No elevator 34746, Elevator 324527
# Actual difference: 289781
# Actual percent difference: 834.00%
# --------------------------------------------------
# Pair: No elevator idx 1017, Elevator idx 64
# Actual prices: No elevator 237031, Elevator 500000
# Actual difference: 262969
# Actual percent difference: 110.94%
# --------------------------------------------------
# Pair: No elevator idx 1017, Elevator idx 751
# Actual prices: No elevator 237031, Elevator 405858
# Actual difference: 168827
# Actual percent difference: 71.23%
# --------------------------------------------------
# Pair: No elevator idx 1028, Elevator idx 105
# Actual prices: No elevator 413944, Elevator 500796
# Actual difference: 86852
# Actual percent difference: 20.98%
# --------------------------------------------------
# Pair: No elevator idx 1028, Elevator idx 1080
# Actual prices: No elevator 413944, Elevator 324527
# Actual difference: -89417
# Actual percent difference: -21.60%
# --------------------------------------------------
# Pair: No elevator idx 1030, Elevator idx 105
# Actual prices: No elevator 419107, Elevator 500796
# Actual difference: 81689
# Actual percent difference: 19.49%
# --------------------------------------------------
# Pair: No elevator idx 1030, Elevator idx 1080
# Actual prices: No elevator 419107, Elevator 324527
# Actual difference: -94580
# Actual percent difference: -22.57%
# --------------------------------------------------
# Summary for floor 0:
#   Mean elevator effect:   542.21%
#   Median elevator effect: -0.00%
#   Min effect: -78.96%
#   Max effect: 7839.08%
# ================================================================================
# Floor 1 → 186 matched pairs
# ================================================================================
# Pair: No elevator idx 2, Elevator idx 149
# Actual prices: No elevator 198738, Elevator 78000
# Actual difference: -120738
# Actual percent difference: -60.75%
# --------------------------------------------------
# Pair: No elevator idx 2, Elevator idx 799
# Actual prices: No elevator 198738, Elevator 77923
# Actual difference: -120815
# Actual percent difference: -60.79%
# --------------------------------------------------
# Pair: No elevator idx 6, Elevator idx 163
# Actual prices: No elevator 235348, Elevator 320000
# Actual difference: 84652
# Actual percent difference: 35.97%
# --------------------------------------------------
# Pair: No elevator idx 6, Elevator idx 380
# Actual prices: No elevator 235348, Elevator 389508
# Actual difference: 154160
# Actual percent difference: 65.50%
# --------------------------------------------------
# Pair: No elevator idx 7, Elevator idx 149
# Actual prices: No elevator 310000, Elevator 78000
# Actual difference: -232000
# Actual percent difference: -74.84%
# --------------------------------------------------
# Pair: No elevator idx 7, Elevator idx 799
# Actual prices: No elevator 310000, Elevator 77923
# Actual difference: -232077
# Actual percent difference: -74.86%
# --------------------------------------------------
# Pair: No elevator idx 34, Elevator idx 747
# Actual prices: No elevator 370956, Elevator 79823
# Actual difference: -291133
# Actual percent difference: -78.48%
# --------------------------------------------------
# Pair: No elevator idx 34, Elevator idx 799
# Actual prices: No elevator 370956, Elevator 77923
# Actual difference: -293033
# Actual percent difference: -78.99%
# --------------------------------------------------
# Pair: No elevator idx 46, Elevator idx 747
# Actual prices: No elevator 500796, Elevator 79823
# Actual difference: -420973
# Actual percent difference: -84.06%
# --------------------------------------------------
# Pair: No elevator idx 46, Elevator idx 380
# Actual prices: No elevator 500796, Elevator 389508
# Actual difference: -111288
# Actual percent difference: -22.22%
# --------------------------------------------------
# Pair: No elevator idx 48, Elevator idx 714
# Actual prices: No elevator 797564, Elevator 77333
# Actual difference: -720231
# Actual percent difference: -90.30%
# --------------------------------------------------
# Pair: No elevator idx 48, Elevator idx 497
# Actual prices: No elevator 797564, Elevator 612084
# Actual difference: -185480
# Actual percent difference: -23.26%
# --------------------------------------------------
# Pair: No elevator idx 53, Elevator idx 149
# Actual prices: No elevator 574988, Elevator 78000
# Actual difference: -496988
# Actual percent difference: -86.43%
# --------------------------------------------------
# Pair: No elevator idx 53, Elevator idx 799
# Actual prices: No elevator 574988, Elevator 77923
# Actual difference: -497065
# Actual percent difference: -86.45%
# --------------------------------------------------
# Pair: No elevator idx 62, Elevator idx 183
# Actual prices: No elevator 741920, Elevator 741920
# Actual difference: 0
# Actual percent difference: 0.00%
# --------------------------------------------------
# Pair: No elevator idx 62, Elevator idx 44
# Actual prices: No elevator 741920, Elevator 400637
# Actual difference: -341283
# Actual percent difference: -46.00%
# --------------------------------------------------
# Pair: No elevator idx 98, Elevator idx 500
# Actual prices: No elevator 400000, Elevator 445152
# Actual difference: 45152
# Actual percent difference: 11.29%
# --------------------------------------------------
# Pair: No elevator idx 98, Elevator idx 747
# Actual prices: No elevator 400000, Elevator 79823
# Actual difference: -320177
# Actual percent difference: -80.04%
# --------------------------------------------------
# Pair: No elevator idx 184, Elevator idx 186
# Actual prices: No elevator 482248, Elevator 500796
# Actual difference: 18548
# Actual percent difference: 3.85%
# --------------------------------------------------
# Pair: No elevator idx 196, Elevator idx 380
# Actual prices: No elevator 25000, Elevator 389508
# Actual difference: 364508
# Actual percent difference: 1458.03%
# --------------------------------------------------
# Pair: No elevator idx 196, Elevator idx 747
# Actual prices: No elevator 25000, Elevator 79823
# Actual difference: 54823
# Actual percent difference: 219.29%
# --------------------------------------------------
# Pair: No elevator idx 202, Elevator idx 149
# Actual prices: No elevator 303337, Elevator 78000
# Actual difference: -225337
# Actual percent difference: -74.29%
# --------------------------------------------------
# Pair: No elevator idx 202, Elevator idx 799
# Actual prices: No elevator 303337, Elevator 77923
# Actual difference: -225414
# Actual percent difference: -74.31%
# --------------------------------------------------
# Pair: No elevator idx 270, Elevator idx 299
# Actual prices: No elevator 392246, Elevator 463700
# Actual difference: 71454
# Actual percent difference: 18.22%
# --------------------------------------------------
# Pair: No elevator idx 270, Elevator idx 300
# Actual prices: No elevator 392246, Elevator 463700
# Actual difference: 71454
# Actual percent difference: 18.22%
# --------------------------------------------------
# Pair: No elevator idx 288, Elevator idx 44
# Actual prices: No elevator 156898, Elevator 400637
# Actual difference: 243739
# Actual percent difference: 155.35%
# --------------------------------------------------
# Pair: No elevator idx 288, Elevator idx 714
# Actual prices: No elevator 156898, Elevator 77333
# Actual difference: -79565
# Actual percent difference: -50.71%
# --------------------------------------------------
# Pair: No elevator idx 292, Elevator idx 714
# Actual prices: No elevator 686276, Elevator 77333
# Actual difference: -608943
# Actual percent difference: -88.73%
# --------------------------------------------------
# Pair: No elevator idx 292, Elevator idx 497
# Actual prices: No elevator 686276, Elevator 612084
# Actual difference: -74192
# Actual percent difference: -10.81%
# --------------------------------------------------
# Pair: No elevator idx 347, Elevator idx 163
# Actual prices: No elevator 470695, Elevator 320000
# Actual difference: -150695
# Actual percent difference: -32.02%
# --------------------------------------------------
# Pair: No elevator idx 347, Elevator idx 183
# Actual prices: No elevator 470695, Elevator 741920
# Actual difference: 271225
# Actual percent difference: 57.62%
# --------------------------------------------------
# Pair: No elevator idx 403, Elevator idx 221
# Actual prices: No elevator 575294, Elevator 519344
# Actual difference: -55950
# Actual percent difference: -9.73%
# --------------------------------------------------
# Pair: No elevator idx 403, Elevator idx 716
# Actual prices: No elevator 575294, Elevator 284682
# Actual difference: -290612
# Actual percent difference: -50.52%
# --------------------------------------------------
# Pair: No elevator idx 412, Elevator idx 747
# Actual prices: No elevator 225000, Elevator 79823
# Actual difference: -145177
# Actual percent difference: -64.52%
# --------------------------------------------------
# Pair: No elevator idx 412, Elevator idx 799
# Actual prices: No elevator 225000, Elevator 77923
# Actual difference: -147077
# Actual percent difference: -65.37%
# --------------------------------------------------
# Pair: No elevator idx 431, Elevator idx 90
# Actual prices: No elevator 215157, Elevator 366096
# Actual difference: 150939
# Actual percent difference: 70.15%
# --------------------------------------------------
# Pair: No elevator idx 431, Elevator idx 300
# Actual prices: No elevator 215157, Elevator 463700
# Actual difference: 248543
# Actual percent difference: 115.52%
# --------------------------------------------------
# Pair: No elevator idx 447, Elevator idx 747
# Actual prices: No elevator 235348, Elevator 79823
# Actual difference: -155525
# Actual percent difference: -66.08%
# --------------------------------------------------
# Pair: No elevator idx 447, Elevator idx 799
# Actual prices: No elevator 235348, Elevator 77923
# Actual difference: -157425
# Actual percent difference: -66.89%
# --------------------------------------------------
# Pair: No elevator idx 448, Elevator idx 747
# Actual prices: No elevator 235348, Elevator 79823
# Actual difference: -155525
# Actual percent difference: -66.08%
# --------------------------------------------------
# Pair: No elevator idx 448, Elevator idx 799
# Actual prices: No elevator 235348, Elevator 77923
# Actual difference: -157425
# Actual percent difference: -66.89%
# --------------------------------------------------
# Pair: No elevator idx 505, Elevator idx 90
# Actual prices: No elevator 209198, Elevator 366096
# Actual difference: 156898
# Actual percent difference: 75.00%
# --------------------------------------------------
# Pair: No elevator idx 505, Elevator idx 549
# Actual prices: No elevator 209198, Elevator 188278
# Actual difference: -20920
# Actual percent difference: -10.00%
# --------------------------------------------------
# Pair: No elevator idx 590, Elevator idx 536
# Actual prices: No elevator 287647, Elevator 333864
# Actual difference: 46217
# Actual percent difference: 16.07%
# --------------------------------------------------
# Pair: No elevator idx 590, Elevator idx 163
# Actual prices: No elevator 287647, Elevator 320000
# Actual difference: 32353
# Actual percent difference: 11.25%
# --------------------------------------------------
# Pair: No elevator idx 607, Elevator idx 380
# Actual prices: No elevator 198738, Elevator 389508
# Actual difference: 190770
# Actual percent difference: 95.99%
# --------------------------------------------------
# Pair: No elevator idx 614, Elevator idx 163
# Actual prices: No elevator 355636, Elevator 320000
# Actual difference: -35636
# Actual percent difference: -10.02%
# --------------------------------------------------
# Pair: No elevator idx 614, Elevator idx 149
# Actual prices: No elevator 355636, Elevator 78000
# Actual difference: -277636
# Actual percent difference: -78.07%
# --------------------------------------------------
# Pair: No elevator idx 615, Elevator idx 163
# Actual prices: No elevator 183048, Elevator 320000
# Actual difference: 136952
# Actual percent difference: 74.82%
# --------------------------------------------------
# Pair: No elevator idx 615, Elevator idx 380
# Actual prices: No elevator 183048, Elevator 389508
# Actual difference: 206460
# Actual percent difference: 112.79%
# --------------------------------------------------
# Pair: No elevator idx 622, Elevator idx 497
# Actual prices: No elevator 630632, Elevator 612084
# Actual difference: -18548
# Actual percent difference: -2.94%
# --------------------------------------------------
# Pair: No elevator idx 625, Elevator idx 299
# Actual prices: No elevator 445152, Elevator 463700
# Actual difference: 18548
# Actual percent difference: 4.17%
# --------------------------------------------------
# Pair: No elevator idx 625, Elevator idx 300
# Actual prices: No elevator 445152, Elevator 463700
# Actual difference: 18548
# Actual percent difference: 4.17%
# --------------------------------------------------
# Pair: No elevator idx 638, Elevator idx 380
# Actual prices: No elevator 251037, Elevator 389508
# Actual difference: 138471
# Actual percent difference: 55.16%
# --------------------------------------------------
# Pair: No elevator idx 638, Elevator idx 747
# Actual prices: No elevator 251037, Elevator 79823
# Actual difference: -171214
# Actual percent difference: -68.20%
# --------------------------------------------------
# Pair: No elevator idx 655, Elevator idx 183
# Actual prices: No elevator 784492, Elevator 741920
# Actual difference: -42572
# Actual percent difference: -5.43%
# --------------------------------------------------
# Pair: No elevator idx 655, Elevator idx 44
# Actual prices: No elevator 784492, Elevator 400637
# Actual difference: -383855
# Actual percent difference: -48.93%
# --------------------------------------------------
# Pair: No elevator idx 656, Elevator idx 500
# Actual prices: No elevator 287647, Elevator 445152
# Actual difference: 157505
# Actual percent difference: 54.76%
# --------------------------------------------------
# Pair: No elevator idx 656, Elevator idx 149
# Actual prices: No elevator 287647, Elevator 78000
# Actual difference: -209647
# Actual percent difference: -72.88%
# --------------------------------------------------
# Pair: No elevator idx 673, Elevator idx 549
# Actual prices: No elevator 556440, Elevator 188278
# Actual difference: -368162
# Actual percent difference: -66.16%
# --------------------------------------------------
# Pair: No elevator idx 673, Elevator idx 299
# Actual prices: No elevator 556440, Elevator 463700
# Actual difference: -92740
# Actual percent difference: -16.67%
# --------------------------------------------------
# Pair: No elevator idx 674, Elevator idx 536
# Actual prices: No elevator 522995, Elevator 333864
# Actual difference: -189131
# Actual percent difference: -36.16%
# --------------------------------------------------
# Pair: No elevator idx 674, Elevator idx 163
# Actual prices: No elevator 522995, Elevator 320000
# Actual difference: -202995
# Actual percent difference: -38.81%
# --------------------------------------------------
# Pair: No elevator idx 675, Elevator idx 714
# Actual prices: No elevator 816112, Elevator 77333
# Actual difference: -738779
# Actual percent difference: -90.52%
# --------------------------------------------------
# Pair: No elevator idx 675, Elevator idx 497
# Actual prices: No elevator 816112, Elevator 612084
# Actual difference: -204028
# Actual percent difference: -25.00%
# --------------------------------------------------
# Pair: No elevator idx 682, Elevator idx 183
# Actual prices: No elevator 816112, Elevator 741920
# Actual difference: -74192
# Actual percent difference: -9.09%
# --------------------------------------------------
# Pair: No elevator idx 682, Elevator idx 44
# Actual prices: No elevator 816112, Elevator 400637
# Actual difference: -415475
# Actual percent difference: -50.91%
# --------------------------------------------------
# Pair: No elevator idx 688, Elevator idx 497
# Actual prices: No elevator 470695, Elevator 612084
# Actual difference: 141389
# Actual percent difference: 30.04%
# --------------------------------------------------
# Pair: No elevator idx 688, Elevator idx 183
# Actual prices: No elevator 470695, Elevator 741920
# Actual difference: 271225
# Actual percent difference: 57.62%
# --------------------------------------------------
# Pair: No elevator idx 690, Elevator idx 90
# Actual prices: No elevator 259672, Elevator 366096
# Actual difference: 106424
# Actual percent difference: 40.98%
# --------------------------------------------------
# Pair: No elevator idx 690, Elevator idx 163
# Actual prices: No elevator 259672, Elevator 320000
# Actual difference: 60328
# Actual percent difference: 23.23%
# --------------------------------------------------
# Pair: No elevator idx 697, Elevator idx 90
# Actual prices: No elevator 630632, Elevator 366096
# Actual difference: -264536
# Actual percent difference: -41.95%
# --------------------------------------------------
# Pair: No elevator idx 697, Elevator idx 536
# Actual prices: No elevator 630632, Elevator 333864
# Actual difference: -296768
# Actual percent difference: -47.06%
# --------------------------------------------------
# Pair: No elevator idx 701, Elevator idx 497
# Actual prices: No elevator 210000, Elevator 612084
# Actual difference: 402084
# Actual percent difference: 191.47%
# --------------------------------------------------
# Pair: No elevator idx 701, Elevator idx 149
# Actual prices: No elevator 210000, Elevator 78000
# Actual difference: -132000
# Actual percent difference: -62.86%
# --------------------------------------------------
# Pair: No elevator idx 703, Elevator idx 747
# Actual prices: No elevator 277187, Elevator 79823
# Actual difference: -197364
# Actual percent difference: -71.20%
# --------------------------------------------------
# Pair: No elevator idx 703, Elevator idx 799
# Actual prices: No elevator 277187, Elevator 77923
# Actual difference: -199264
# Actual percent difference: -71.89%
# --------------------------------------------------
# Pair: No elevator idx 707, Elevator idx 497
# Actual prices: No elevator 339946, Elevator 612084
# Actual difference: 272138
# Actual percent difference: 80.05%
# --------------------------------------------------
# Pair: No elevator idx 707, Elevator idx 183
# Actual prices: No elevator 339946, Elevator 741920
# Actual difference: 401974
# Actual percent difference: 118.25%
# --------------------------------------------------
# Pair: No elevator idx 708, Elevator idx 714
# Actual prices: No elevator 519344, Elevator 77333
# Actual difference: -442011
# Actual percent difference: -85.11%
# --------------------------------------------------
# Pair: No elevator idx 709, Elevator idx 90
# Actual prices: No elevator 463700, Elevator 366096
# Actual difference: -97604
# Actual percent difference: -21.05%
# --------------------------------------------------
# Pair: No elevator idx 709, Elevator idx 163
# Actual prices: No elevator 463700, Elevator 320000
# Actual difference: -143700
# Actual percent difference: -30.99%
# --------------------------------------------------
# Pair: No elevator idx 713, Elevator idx 536
# Actual prices: No elevator 533565, Elevator 333864
# Actual difference: -199701
# Actual percent difference: -37.43%
# --------------------------------------------------
# Pair: No elevator idx 713, Elevator idx 163
# Actual prices: No elevator 533565, Elevator 320000
# Actual difference: -213565
# Actual percent difference: -40.03%
# --------------------------------------------------
# Pair: No elevator idx 722, Elevator idx 380
# Actual prices: No elevator 259280, Elevator 389508
# Actual difference: 130228
# Actual percent difference: 50.23%
# --------------------------------------------------
# Pair: No elevator idx 722, Elevator idx 747
# Actual prices: No elevator 259280, Elevator 79823
# Actual difference: -179457
# Actual percent difference: -69.21%
# --------------------------------------------------
# Pair: No elevator idx 723, Elevator idx 380
# Actual prices: No elevator 24476, Elevator 389508
# Actual difference: 365032
# Actual percent difference: 1491.39%
# --------------------------------------------------
# Pair: No elevator idx 723, Elevator idx 747
# Actual prices: No elevator 24476, Elevator 79823
# Actual difference: 55347
# Actual percent difference: 226.13%
# --------------------------------------------------
# Pair: No elevator idx 727, Elevator idx 149
# Actual prices: No elevator 316222, Elevator 78000
# Actual difference: -238222
# Actual percent difference: -75.33%
# --------------------------------------------------
# Pair: No elevator idx 727, Elevator idx 799
# Actual prices: No elevator 316222, Elevator 77923
# Actual difference: -238299
# Actual percent difference: -75.36%
# --------------------------------------------------
# Pair: No elevator idx 728, Elevator idx 380
# Actual prices: No elevator 246800, Elevator 389508
# Actual difference: 142708
# Actual percent difference: 57.82%
# --------------------------------------------------
# Pair: No elevator idx 728, Elevator idx 500
# Actual prices: No elevator 246800, Elevator 445152
# Actual difference: 198352
# Actual percent difference: 80.37%
# --------------------------------------------------
# Pair: No elevator idx 731, Elevator idx 714
# Actual prices: No elevator 315559, Elevator 77333
# Actual difference: -238226
# Actual percent difference: -75.49%
# --------------------------------------------------
# Pair: No elevator idx 735, Elevator idx 299
# Actual prices: No elevator 387776, Elevator 463700
# Actual difference: 75924
# Actual percent difference: 19.58%
# --------------------------------------------------
# Pair: No elevator idx 735, Elevator idx 300
# Actual prices: No elevator 387776, Elevator 463700
# Actual difference: 75924
# Actual percent difference: 19.58%
# --------------------------------------------------
# Pair: No elevator idx 739, Elevator idx 183
# Actual prices: No elevator 796622, Elevator 741920
# Actual difference: -54702
# Actual percent difference: -6.87%
# --------------------------------------------------
# Pair: No elevator idx 739, Elevator idx 44
# Actual prices: No elevator 796622, Elevator 400637
# Actual difference: -395985
# Actual percent difference: -49.71%
# --------------------------------------------------
# ...
# Pair: No elevator idx 906, Elevator idx 718
# Actual prices: No elevator 200659, Elevator 348113
# Actual difference: 147454
# Actual percent difference: 73.48%
# --------------------------------------------------
# Pair: No elevator idx 914, Elevator idx 555
# Actual prices: No elevator 196666, Elevator 355636
# Actual difference: 158970
# Actual percent difference: 80.83%
# --------------------------------------------------
# Pair: No elevator idx 914, Elevator idx 718
# Actual prices: No elevator 196666, Elevator 348113
# Actual difference: 151447
# Actual percent difference: 77.01%
# --------------------------------------------------
# Pair: No elevator idx 943, Elevator idx 909
# Actual prices: No elevator 302840, Elevator 304695
# Actual difference: 1855
# Actual percent difference: 0.61%
# --------------------------------------------------
# Pair: No elevator idx 943, Elevator idx 491
# Actual prices: No elevator 302840, Elevator 303337
# Actual difference: 497
# Actual percent difference: 0.16%
# --------------------------------------------------
# Pair: No elevator idx 963, Elevator idx 916
# Actual prices: No elevator 307246, Elevator 307864
# Actual difference: 618
# Actual percent difference: 0.20%
# --------------------------------------------------
# Pair: No elevator idx 963, Elevator idx 575
# Actual prices: No elevator 307246, Elevator 303337
# Actual difference: -3909
# Actual percent difference: -1.27%
# --------------------------------------------------
# Pair: No elevator idx 967, Elevator idx 555
# Actual prices: No elevator 201187, Elevator 355636
# Actual difference: 154449
# Actual percent difference: 76.77%
# --------------------------------------------------
# Pair: No elevator idx 967, Elevator idx 718
# Actual prices: No elevator 201187, Elevator 348113
# Actual difference: 146926
# Actual percent difference: 73.03%
# --------------------------------------------------
# Pair: No elevator idx 970, Elevator idx 555
# Actual prices: No elevator 202805, Elevator 355636
# Actual difference: 152831
# Actual percent difference: 75.36%
# --------------------------------------------------
# Pair: No elevator idx 970, Elevator idx 718
# Actual prices: No elevator 202805, Elevator 348113
# Actual difference: 145308
# Actual percent difference: 71.65%
# --------------------------------------------------
# Pair: No elevator idx 973, Elevator idx 909
# Actual prices: No elevator 303126, Elevator 304695
# Actual difference: 1569
# Actual percent difference: 0.52%
# --------------------------------------------------
# Pair: No elevator idx 973, Elevator idx 491
# Actual prices: No elevator 303126, Elevator 303337
# Actual difference: 211
# Actual percent difference: 0.07%
# --------------------------------------------------
# Pair: No elevator idx 1124, Elevator idx 953
# Actual prices: No elevator 227408, Elevator 302810
# Actual difference: 75402
# Actual percent difference: 33.16%
# --------------------------------------------------
# Pair: No elevator idx 1124, Elevator idx 491
# Actual prices: No elevator 227408, Elevator 303337
# Actual difference: 75929
# Actual percent difference: 33.39%
# --------------------------------------------------
# Pair: No elevator idx 1161, Elevator idx 956
# Actual prices: No elevator 221032, Elevator 308495
# Actual difference: 87463
# Actual percent difference: 39.57%
# --------------------------------------------------
# Pair: No elevator idx 1161, Elevator idx 966
# Actual prices: No elevator 221032, Elevator 310538
# Actual difference: 89506
# Actual percent difference: 40.49%
# --------------------------------------------------
# Pair: No elevator idx 1178, Elevator idx 555
# Actual prices: No elevator 225710, Elevator 355636
# Actual difference: 129926
# Actual percent difference: 57.56%
# --------------------------------------------------
# Pair: No elevator idx 1178, Elevator idx 953
# Actual prices: No elevator 225710, Elevator 302810
# Actual difference: 77100
# Actual percent difference: 34.16%
# --------------------------------------------------
# Summary for floor 7:
#   Mean elevator effect:   30.72%
#   Median elevator effect: 34.68%
#   Min effect: -46.50%
#   Max effect: 80.83%
# ================================================================================
# Floor 8 → 0 matched pairs
# ================================================================================
# ⚠️ No valid pairs on this floor.
# ================================================================================
# Floor 9 → 24 matched pairs
# ================================================================================
# Pair: No elevator idx 585, Elevator idx 530
# Actual prices: No elevator 254108, Elevator 254108
# Actual difference: 0
# Actual percent difference: 0.00%
# --------------------------------------------------
# Pair: No elevator idx 585, Elevator idx 551
# Actual prices: No elevator 254108, Elevator 444545
# Actual difference: 190437
# Actual percent difference: 74.94%
# --------------------------------------------------
# Pair: No elevator idx 629, Elevator idx 551
# Actual prices: No elevator 450000, Elevator 444545
# Actual difference: -5455
# Actual percent difference: -1.21%
# --------------------------------------------------
# Pair: No elevator idx 629, Elevator idx 214
# Actual prices: No elevator 450000, Elevator 260000
# Actual difference: -190000
# Actual percent difference: -42.22%
# --------------------------------------------------
# Pair: No elevator idx 1128, Elevator idx 551
# Actual prices: No elevator 447144, Elevator 444545
# Actual difference: -2599
# Actual percent difference: -0.58%
# --------------------------------------------------
# Pair: No elevator idx 1128, Elevator idx 214
# Actual prices: No elevator 447144, Elevator 260000
# Actual difference: -187144
# Actual percent difference: -41.85%
# --------------------------------------------------
# Pair: No elevator idx 1135, Elevator idx 551
# Actual prices: No elevator 448066, Elevator 444545
# Actual difference: -3521
# Actual percent difference: -0.79%
# --------------------------------------------------
# Pair: No elevator idx 1135, Elevator idx 214
# Actual prices: No elevator 448066, Elevator 260000
# Actual difference: -188066
# Actual percent difference: -41.97%
# --------------------------------------------------
# Pair: No elevator idx 1141, Elevator idx 551
# Actual prices: No elevator 446996, Elevator 444545
# Actual difference: -2451
# Actual percent difference: -0.55%
# --------------------------------------------------
# Pair: No elevator idx 1141, Elevator idx 214
# Actual prices: No elevator 446996, Elevator 260000
# Actual difference: -186996
# Actual percent difference: -41.83%
# --------------------------------------------------
# Pair: No elevator idx 1147, Elevator idx 551
# Actual prices: No elevator 444291, Elevator 444545
# Actual difference: 254
# Actual percent difference: 0.06%
# --------------------------------------------------
# Pair: No elevator idx 1147, Elevator idx 214
# Actual prices: No elevator 444291, Elevator 260000
# Actual difference: -184291
# Actual percent difference: -41.48%
# --------------------------------------------------
# Pair: No elevator idx 1167, Elevator idx 551
# Actual prices: No elevator 453015, Elevator 444545
# Actual difference: -8470
# Actual percent difference: -1.87%
# --------------------------------------------------
# Pair: No elevator idx 1167, Elevator idx 214
# Actual prices: No elevator 453015, Elevator 260000
# Actual difference: -193015
# Actual percent difference: -42.61%
# --------------------------------------------------
# Pair: No elevator idx 1170, Elevator idx 530
# Actual prices: No elevator 256280, Elevator 254108
# Actual difference: -2172
# Actual percent difference: -0.85%
# --------------------------------------------------
# Pair: No elevator idx 1170, Elevator idx 551
# Actual prices: No elevator 256280, Elevator 444545
# Actual difference: 188265
# Actual percent difference: 73.46%
# --------------------------------------------------
# Pair: No elevator idx 1174, Elevator idx 530
# Actual prices: No elevator 248757, Elevator 254108
# Actual difference: 5351
# Actual percent difference: 2.15%
# --------------------------------------------------
# Pair: No elevator idx 1174, Elevator idx 551
# Actual prices: No elevator 248757, Elevator 444545
# Actual difference: 195788
# Actual percent difference: 78.71%
# --------------------------------------------------
# Pair: No elevator idx 1176, Elevator idx 551
# Actual prices: No elevator 450998, Elevator 444545
# Actual difference: -6453
# Actual percent difference: -1.43%
# --------------------------------------------------
# Pair: No elevator idx 1176, Elevator idx 214
# Actual prices: No elevator 450998, Elevator 260000
# Actual difference: -190998
# Actual percent difference: -42.35%
# --------------------------------------------------
# Pair: No elevator idx 1188, Elevator idx 530
# Actual prices: No elevator 251308, Elevator 254108
# Actual difference: 2800
# Actual percent difference: 1.11%
# --------------------------------------------------
# Pair: No elevator idx 1188, Elevator idx 551
# Actual prices: No elevator 251308, Elevator 444545
# Actual difference: 193237
# Actual percent difference: 76.89%
# --------------------------------------------------
# Pair: No elevator idx 1197, Elevator idx 530
# Actual prices: No elevator 256028, Elevator 254108
# Actual difference: -1920
# Actual percent difference: -0.75%
# --------------------------------------------------
# Pair: No elevator idx 1197, Elevator idx 551
# Actual prices: No elevator 256028, Elevator 444545
# Actual difference: 188517
# Actual percent difference: 73.63%
# --------------------------------------------------
# Summary for floor 9:
#   Mean elevator effect:   3.28%
#   Median elevator effect: -0.77%
#   Min effect: -42.61%
#   Max effect: 78.71%
# ================================================================================
# Floor 10 → 6 matched pairs
# ================================================================================
# Pair: No elevator idx 649, Elevator idx 1148
# Actual prices: No elevator 10000, Elevator 558369
# Actual difference: 548369
# Actual percent difference: 5483.69%
# --------------------------------------------------
# Pair: No elevator idx 649, Elevator idx 9
# Actual prices: No elevator 10000, Elevator 550000
# Actual difference: 540000
# Actual percent difference: 5400.00%
# --------------------------------------------------
# Pair: No elevator idx 1131, Elevator idx 1148
# Actual prices: No elevator 9933, Elevator 558369
# Actual difference: 548436
# Actual percent difference: 5521.35%
# --------------------------------------------------
# Pair: No elevator idx 1131, Elevator idx 9
# Actual prices: No elevator 9933, Elevator 550000
# Actual difference: 540067
# Actual percent difference: 5437.10%
# --------------------------------------------------
# Pair: No elevator idx 1160, Elevator idx 1148
# Actual prices: No elevator 10236, Elevator 558369
# Actual difference: 548133
# Actual percent difference: 5354.95%
# --------------------------------------------------
# Pair: No elevator idx 1160, Elevator idx 9
# Actual prices: No elevator 10236, Elevator 550000
# Actual difference: 539764
# Actual percent difference: 5273.19%
# --------------------------------------------------
# Summary for floor 10:
#   Mean elevator effect:   5411.71%
#   Median elevator effect: 5418.55%
#   Min effect: 5273.19%
#   Max effect: 5521.35%
# ================================================================================
# Floor 11 → 22 matched pairs
# ================================================================================
# Pair: No elevator idx 66, Elevator idx 115
# Actual prices: No elevator 537892, Elevator 303337
# Actual difference: -234555
# Actual percent difference: -43.61%
# --------------------------------------------------
# Pair: No elevator idx 66, Elevator idx 922
# Actual prices: No elevator 537892, Elevator 289997
# Actual difference: -247895
# Actual percent difference: -46.09%
# --------------------------------------------------
# Pair: No elevator idx 409, Elevator idx 219
# Actual prices: No elevator 408056, Elevator 1400000
# Actual difference: 991944
# Actual percent difference: 243.09%
# --------------------------------------------------
# Pair: No elevator idx 409, Elevator idx 115
# Actual prices: No elevator 408056, Elevator 303337
# Actual difference: -104719
# Actual percent difference: -25.66%
# --------------------------------------------------
# Pair: No elevator idx 502, Elevator idx 233
# Actual prices: No elevator 853208, Elevator 1101751
# Actual difference: 248543
# Actual percent difference: 29.13%
# --------------------------------------------------
# Pair: No elevator idx 502, Elevator idx 164
# Actual prices: No elevator 853208, Elevator 580000
# Actual difference: -273208
# Actual percent difference: -32.02%
# --------------------------------------------------
# Pair: No elevator idx 595, Elevator idx 115
# Actual prices: No elevator 290000, Elevator 303337
# Actual difference: 13337
# Actual percent difference: 4.60%
# --------------------------------------------------
# Pair: No elevator idx 595, Elevator idx 885
# Actual prices: No elevator 290000, Elevator 509295
# Actual difference: 219295
# Actual percent difference: 75.62%
# --------------------------------------------------
# Pair: No elevator idx 633, Elevator idx 1195
# Actual prices: No elevator 445152, Elevator 380392
# Actual difference: -64760
# Actual percent difference: -14.55%
# --------------------------------------------------
# Pair: No elevator idx 633, Elevator idx 1190
# Actual prices: No elevator 445152, Elevator 374489
# Actual difference: -70663
# Actual percent difference: -15.87%
# --------------------------------------------------
# Pair: No elevator idx 677, Elevator idx 115
# Actual prices: No elevator 686276, Elevator 303337
# Actual difference: -382939
# Actual percent difference: -55.80%
# --------------------------------------------------
# Pair: No elevator idx 677, Elevator idx 922
# Actual prices: No elevator 686276, Elevator 289997
# Actual difference: -396279
# Actual percent difference: -57.74%
# --------------------------------------------------
# Pair: No elevator idx 693, Elevator idx 164
# Actual prices: No elevator 890304, Elevator 580000
# Actual difference: -310304
# Actual percent difference: -34.85%
# --------------------------------------------------
# Pair: No elevator idx 693, Elevator idx 870
# Actual prices: No elevator 890304, Elevator 509583
# Actual difference: -380721
# Actual percent difference: -42.76%
# --------------------------------------------------
# Pair: No elevator idx 1140, Elevator idx 1195
# Actual prices: No elevator 437141, Elevator 380392
# Actual difference: -56749
# Actual percent difference: -12.98%
# --------------------------------------------------
# Pair: No elevator idx 1140, Elevator idx 1190
# Actual prices: No elevator 437141, Elevator 374489
# Actual difference: -62652
# Actual percent difference: -14.33%
# --------------------------------------------------
# Pair: No elevator idx 1150, Elevator idx 1195
# Actual prices: No elevator 442097, Elevator 380392
# Actual difference: -61705
# Actual percent difference: -13.96%
# --------------------------------------------------
# Pair: No elevator idx 1150, Elevator idx 1190
# Actual prices: No elevator 442097, Elevator 374489
# Actual difference: -67608
# Actual percent difference: -15.29%
# --------------------------------------------------
# Pair: No elevator idx 1193, Elevator idx 1195
# Actual prices: No elevator 439220, Elevator 380392
# Actual difference: -58828
# Actual percent difference: -13.39%
# --------------------------------------------------
# Pair: No elevator idx 1193, Elevator idx 1190
# Actual prices: No elevator 439220, Elevator 374489
# Actual difference: -64731
# Actual percent difference: -14.74%
# --------------------------------------------------
# Pair: No elevator idx 1196, Elevator idx 1195
# Actual prices: No elevator 447394, Elevator 380392
# Actual difference: -67002
# Actual percent difference: -14.98%
# --------------------------------------------------
# Pair: No elevator idx 1196, Elevator idx 1190
# Actual prices: No elevator 447394, Elevator 374489
# Actual difference: -72905
# Actual percent difference: -16.30%
# --------------------------------------------------
# Summary for floor 11:
#   Mean elevator effect:   -6.02%
#   Median elevator effect: -15.13%
#   Min effect: -57.74%
#   Max effect: 243.09%

# %%
summary_rows = []
for f, stats in all_stats.items():
    if stats:  # skip empty floors
        summary_rows.append({
            "Floor": f,
            "Pairs": stats["count"],
            "Mean %": round(stats["mean"], 2),
            "Median %": round(stats["median"], 2),
            "Min %": round(stats["min"], 2),
            "Max %": round(stats["max"], 2)
        })

summary_df = pd.DataFrame(summary_rows).sort_values("Floor")
display(summary_df)

print("\n=== Aggregated elevator effect across ALL floors ===")
all_diffs = [pct for stats in all_stats.values() if stats for pct in [stats["mean"]]]
if all_diffs:
    print(f"Overall mean of floor means:   {np.mean(all_diffs):.2f}%")
    print(f"Overall median of floor means: {np.median(all_diffs):.2f}%")
else:
    print("⚠️ No valid comparisons found.")
# Out:
#     Floor  Pairs   Mean %  Median %    Min %    Max %
# 0      -2     16    50.14     48.69   -28.57   127.27
# 1      -1     20     1.90     -0.42   -88.02    85.00
# 2       0     94   542.21     -0.00   -78.96  7839.08
# 3       1    186    18.92    -21.64   -98.92  1491.39
# 4       2    156    -5.10    -25.11   -96.32   518.27
# 5       3    105    56.64     10.00   -69.35   672.41
# 6       4     95    20.40      1.94   -64.92   287.87
# 7       5     56   -31.63    -48.23   -85.65   112.96
# 8       6     73    -6.35     -3.14   -50.14    78.69
# 9       7     36    30.72     34.68   -46.50    80.83
# 10      9     24     3.28     -0.77   -42.61    78.71
# 11     10      6  5411.71   5418.55  5273.19  5521.35
# 12     11     22    -6.02    -15.13   -57.74   243.09
# === Aggregated elevator effect across ALL floors ===
# Overall mean of floor means:   468.22%
# Overall median of floor means: 18.92%

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Right now, the analysis shows that the effect of having an elevator on apartment prices is highly inconsistent across floors, with extreme outliers and widely varying median and mean impacts. Because of this unreliability, we will drop the "مصعد" feature from the model.
